# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Linear Regression.xlsx")

# %%
x = df.bathrooms
y = df.price

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
X_train= X_train.values.reshape(-1, 1)
y_train= y_train.values.reshape(-1, 1)
X_test = X_test.values.reshape(-1, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
l_reg = LinearRegression()

# %%
lreg = l_reg.fit(X_train,y_train)

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train,l_reg.predict(X_train),color = 'black')

# %%
ypred = l_reg.predict(X_test)

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test,ypred,color = 'black')

# %%
from sklearn.metrics import r2_score
print("R2 score of the Price vs Bathrooms Model is - ",r2_score(y_test,ypred))
# Out:
# R2 score of the Price vs Bathrooms Model is -  0.2745034662728696

# %% [markdown]
# -----------
